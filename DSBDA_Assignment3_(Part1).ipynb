# %% [markdown]
# <a href="https://colab.research.google.com/github/aniketbidgar3/DSBDA-LAb/blob/main/DSBDA_Assignment3_(Part1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-69b3120a-46ed-4e04-abd3-cb79b1e17274" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-69b3120a-46ed-4e04-abd3-cb79b1e17274">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("Income.csv")

# %%
df
# Out:
#     Customer_ID   Genre  Age  Annual_Income  Spending_Score
# 0             1  Female   27             35              30
# 1             2    Male   37             32              79
# 2             3  Female   28             20              28
# 3             4  Female   41             46              78
# 4             5    Male   37             39              55
# 5             6  Female   52             34              20
# 6             7  Female   30             37              68
# 7             8  Female   22             32              19
# 8             9  Female   45             49              90
# 9            10    Male   44             44              78
# 10           11    Male   44             23              34
# 11           12    Male   26             36              70
# 12           13  Female   29             40              29
# 13           14    Male   31             28              56
# 14           15    Male   37             44              88
# ...

# %%
df.mean()
# Out:
# <ipython-input-10-210ac482e609>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Customer_ID       10.50
# Age               37.15
# Annual_Income     34.50
# Spending_Score    50.70
# dtype: float64

# %%
df.loc[:,'Age'].mean()
# Out:
# 37.15

# %%
df.mean(axis=1)[0:4]
# Out:
# <ipython-input-12-9b5f18f5caf0>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis=1)[0:4]
# 0    23.25
# 1    37.50
# 2    19.75
# 3    42.25
# dtype: float64

# %%
df.median()
# Out:
# <ipython-input-13-7382d4fa75a9>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Customer_ID       10.5
# Age               37.0
# Annual_Income     35.5
# Spending_Score    50.0
# dtype: float64

# %%
df.loc[:,'Age'].median()
# Out:
# 37.0

# %%
df.median(axis=1)[0:4]
# Out:
# <ipython-input-15-8715d1971848>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median(axis=1)[0:4]
# 0    28.5
# 1    34.5
# 2    24.0
# 3    43.5
# dtype: float64

# %%
df.mode()
# Out:
#     Customer_ID   Genre   Age  Annual_Income  Spending_Score
# 0             1  Female  37.0           23.0            28.0
# 1             2    Male   NaN           32.0            78.0
# 2             3     NaN   NaN           40.0             NaN
# 3             4     NaN   NaN           44.0             NaN
# 4             5     NaN   NaN            NaN             NaN
# 5             6     NaN   NaN            NaN             NaN
# 6             7     NaN   NaN            NaN             NaN
# 7             8     NaN   NaN            NaN             NaN
# 8             9     NaN   NaN            NaN             NaN
# 9            10     NaN   NaN            NaN             NaN
# 10           11     NaN   NaN            NaN             NaN
# 11           12     NaN   NaN            NaN             NaN
# 12           13     NaN   NaN            NaN             NaN
# 13           14     NaN   NaN            NaN             NaN
# ...

# %%
df.loc[:,'Age'].mode()
# Out:
# 0    37
# Name: Age, dtype: int64

# %%
df.min()
# Out:
# Customer_ID            1
# Genre             Female
# Age                   21
# Annual_Income         20
# Spending_Score        16
# dtype: object

# %%
df.loc[:,'Age'].min(skipna = False)
# Out:
# 21

# %%
df.max()
# Out:
# Customer_ID         20
# Genre             Male
# Age                 58
# Annual_Income       49
# Spending_Score      90
# dtype: object

# %%
df.loc[:,'Age'].min(skipna = False)
# Out:
# 21

# %%
df.std()
# Out:
# <ipython-input-22-7e5b37e4523a>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Customer_ID        5.916080
# Age               10.574423
# Annual_Income      8.702692
# Spending_Score    24.550914
# dtype: float64

# %%
df.loc[:,'Age'].std()
# Out:
# 10.574422965468688

# %%
df.std(axis=1)[0:4]
# Out:
# <ipython-input-24-5926a3302e7a>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std(axis=1)[0:4]
# 0    15.195942
# 1    31.691219
# 2    11.786291
# 3    30.313638
# dtype: float64

# %%
df.groupby(['Genre'])['Age'].mean()
# Out:
# Genre
# Female    35.0
# Male      39.3
# Name: Age, dtype: float64

# %%
col_names = ['Customer_ID','Age','Annual_Income','Spending_Score']

# %%
df_u=df.rename(columns= {('Annual_Income'):'Income'},inplace=False)

# %%
(df_u.groupby(['Genre']).Income.mean())
# Out:
# Genre
# Female    35.5
# Male      33.5
# Name: Income, dtype: float64

# %%
from sklearn import preprocessing

# %%
enc = preprocessing.OneHotEncoder()

# %%
enc_df = pd.DataFrame(enc.fit_transform(df[['Genre']]).toarray())

# %%
enc_df
# Out:
#       0    1
# 0   1.0  0.0
# 1   0.0  1.0
# 2   1.0  0.0
# 3   1.0  0.0
# 4   0.0  1.0
# 5   1.0  0.0
# 6   1.0  0.0
# 7   1.0  0.0
# 8   1.0  0.0
# 9   0.0  1.0
# 10  0.0  1.0
# 11  0.0  1.0
# 12  1.0  0.0
# 13  0.0  1.0
# 14  0.0  1.0
# 15  0.0  1.0
# 16  1.0  0.0
# 17  0.0  1.0
# 18  0.0  1.0
# 19  1.0  0.0

# %%
df_encode =df_u.join(enc_df)

# %%
df_encode
# Out:
#     Customer_ID   Genre  Age  Annual_Income  Spending_Score    0    1
# 0             1  Female   27             35              30  1.0  0.0
# 1             2    Male   37             32              79  0.0  1.0
# 2             3  Female   28             20              28  1.0  0.0
# 3             4  Female   41             46              78  1.0  0.0
# 4             5    Male   37             39              55  0.0  1.0
# 5             6  Female   52             34              20  1.0  0.0
# 6             7  Female   30             37              68  1.0  0.0
# 7             8  Female   22             32              19  1.0  0.0
# 8             9  Female   45             49              90  1.0  0.0
# 9            10    Male   44             44              78  0.0  1.0
# 10           11    Male   44             23              34  0.0  1.0
# 11           12    Male   26             36              70  0.0  1.0
# ...

# %%
df
# Out:
#     Customer_ID   Genre  Age  Annual_Income  Spending_Score
# 0             1  Female   27             35              30
# 1             2    Male   37             32              79
# 2             3  Female   28             20              28
# 3             4  Female   41             46              78
# 4             5    Male   37             39              55
# 5             6  Female   52             34              20
# 6             7  Female   30             37              68
# 7             8  Female   22             32              19
# 8             9  Female   45             49              90
# 9            10    Male   44             44              78
# 10           11    Male   44             23              34
# 11           12    Male   26             36              70
# 12           13  Female   29             40              29
# 13           14    Male   31             28              56
# 14           15    Male   37             44              88
# ...
